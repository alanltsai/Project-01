# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

# %%
East_Asia=pd.read_csv("./Regional_Climate_Data/East_Asia-Beijing_China.csv")

# %%
East_Asia.head()
# Out:
#        STATION         NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  CDSD  CLDD  \
# 0  CHM00054511  BEIJING, CH    39.933    116.283         55  1970  1142  1142
# 1  CHM00054511  BEIJING, CH    39.933    116.283         55  1971  1270  1270
# 2  CHM00054511  BEIJING, CH    39.933    116.283         55  1972  1368  1368
# 3  CHM00054511  BEIJING, CH    39.933    116.283         55  1973  1161  1161
# 4  CHM00054511  BEIJING, CH    39.933    116.283         55  1974  1209  1209
#
#    DP01  DP10  ...   FZF6  FZF7  FZF8  FZF9  HDSD  HTDD   PRCP  TAVG  TMAX  \
# 0    62    38  ...     26    18    18  16.0  5873  5873  23.50  52.1  62.3
# 1    57    32  ...     23    23    18  11.0  5838  5838  20.13  52.7  63.1
# 2    50    27  ...     26    24    14  14.0  5624  5624  14.73  52.9  63.4
# 3    75    42  ...     27    20    19  14.0  5485  5485  27.49  53.2  62.8
# 4    56    34  ...     26    22    17  13.0  5539  5539  18.69  52.4  62.8
#
#    TMIN
# 0  41.9
# 1  42.3
# 2  42.4
# ...

# %%
Europe=pd.read_csv("./Regional_Climate_Data/Europe-London_United_Kingdom.csv")

# %%
Europe.head()
# Out:
#        STATION          NAME  DATE   CDSD   CLDD   DP01  DP10  DSND  DT00  \
# 0  UKE00107650  HEATHROW, UK  1970   98.0   98.0  159.0  80.0   5.0     0
# 1  UKE00107650  HEATHROW, UK  1971   63.0   63.0  119.0  61.0   0.0     0
# 2  UKE00107650  HEATHROW, UK  1972   30.0   30.0  143.0  62.0   0.0     0
# 3  UKE00107650  HEATHROW, UK  1973  110.0  110.0  108.0  51.0   0.0     0
# 4  UKE00107650  HEATHROW, UK  1974   16.0   16.0  158.0  82.0   0.0     0
#
#    DT32  ...   FZF6  FZF7  FZF8  FZF9    HDSD    HTDD   PRCP  TAVG  TMAX  TMIN
# 0    52  ...   28.0  23.0   NaN   NaN  4874.0  4874.0  25.84  51.2  58.3  44.1
# 1    30  ...   25.0   NaN   NaN   NaN  4981.0  4981.0  24.36  51.5  58.6  44.3
# 2    21  ...   17.0  17.0  17.0  15.0  4787.0  4787.0  17.49  50.7  57.6  43.8
# 3    56  ...   27.0   NaN   NaN   NaN  5006.0  5006.0  19.12  51.1  58.6  43.5
# 4    10  ...    NaN   NaN   NaN   NaN  4888.0  4888.0  28.73  51.1  58.0  44.2
#
# [5 rows x 33 columns]

# %%
North_Africa=pd.read_csv("./Regional_Climate_Data/Jeddah.csv")

# %%
North_Africa.head()
# Out:
#        STATION                   NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  SA000041024  JEDDAH KING ABDUL, SA      21.7     39.183         17  1978
# 1  SA000041024  JEDDAH KING ABDUL, SA      21.7     39.183         17  1979
# 2  SA000041024  JEDDAH KING ABDUL, SA      21.7     39.183         17  1984
# 3  SA000041024  JEDDAH KING ABDUL, SA      21.7     39.183         17  1985
# 4  SA000041024  JEDDAH KING ABDUL, SA      21.7     39.183         17  1986
#
#      CDSD  CDSD_ATTRIBUTES    CLDD CLDD_ATTRIBUTES       ...        HTDD  \
# 0  6739.0              NaN  6739.0               G       ...         NaN
# 1  7118.0              NaN  7118.0               G       ...         0.0
# 2     NaN              NaN     NaN             NaN       ...         NaN
# 3  6667.0              NaN  6667.0               G       ...         NaN
# 4  6635.0              NaN  6635.0               G       ...         0.0
#
# ...

# %%
Latin_America=pd.read_csv("./Regional_Climate_Data/Latin_America-Buenos_Aires_Argentina.csv")

# %%
Latin_America.head()
# Out:
#        STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  AR000875850  BUENOS AIRES OBSERV, AR   -34.583    -58.483         25  1970
# 1  AR000875850  BUENOS AIRES OBSERV, AR   -34.583    -58.483         25  1971
# 2  AR000875850  BUENOS AIRES OBSERV, AR   -34.583    -58.483         25  1972
# 3  AR000875850  BUENOS AIRES OBSERV, AR   -34.583    -58.483         25  1973
# 4  AR000875850  BUENOS AIRES OBSERV, AR   -34.583    -58.483         25  1974
#
#      CDSD    CLDD  DT00  DT32  ...   DX90  EMNT   EMXT  FZF0  FZF5    HDSD  \
# 0  1701.0  1701.0     0     2  ...   28.0    31   98.0  31.0   NaN  1642.0
# 1  1124.0  1124.0     0     1  ...   17.0    29  100.0  29.0   NaN  1813.0
# 2  1639.0  1639.0     0     1  ...   18.0    31  100.0   NaN  31.0  1696.0
# 3  1252.0  1252.0     0     0  ...   11.0    34   95.0   NaN   NaN  1780.0
# 4  1304.0  1304.0     0     3  ...   11.0    29   98.0  32.0  32.0  1700.0
#
#      HTDD  TAVG  TMAX  TMIN
# ...

# %%
North_America=pd.read_csv("./Regional_Climate_Data/North_American-WashingtonDC_USA.csv")

# %%
North_America.head()
# Out:
#        STATION                                               NAME  LATITUDE  \
# 0  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US   39.1733
# 1  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US   39.1733
# 2  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US   39.1733
# 3  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US   39.1733
# 4  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US   39.1733
#
#    LONGITUDE  ELEVATION  DATE  AWND  CDSD  CLDD  DP01  ...   WDF1  WDF2  WDF5  \
# 0    -76.684       47.5  1970   NaN  1458  1458   111  ...    NaN   NaN   NaN
# 1    -76.684       47.5  1971   NaN  1188  1188   106  ...    NaN   NaN   NaN
# 2    -76.684       47.5  1972   NaN  1029  1029   133  ...    NaN   NaN   NaN
# 3    -76.684       47.5  1973   NaN  1186  1186   120  ...    NaN   NaN   NaN
# 4    -76.684       47.5  1974   NaN  1009  1009   121  ...    NaN   NaN   NaN
#
# ...

# %%
South_Asia=pd.read_csv("./Regional_Climate_Data/South_Asia-Bangkok_Thailand.csv")

# %%
South_Asia.head()
# Out:
#        STATION                    NAME  LATITUDE  LONGITUDE  ELEVATION  DATE  \
# 0  TH000048455  BANGKOK METROPOLIS, TH    13.733    100.567          4  1970
# 1  TH000048455  BANGKOK METROPOLIS, TH    13.733    100.567          4  1971
# 2  TH000048455  BANGKOK METROPOLIS, TH    13.733    100.567          4  1972
# 3  TH000048455  BANGKOK METROPOLIS, TH    13.733    100.567          4  1973
# 4  TH000048455  BANGKOK METROPOLIS, TH    13.733    100.567          4  1974
#
#      CDSD    CLDD   DP01  DP10  ...    DX90  EMNT  EMXP   EMXT  HDSD  HTDD  \
# 0  6567.0  6567.0  143.0  93.0  ...   235.0  65.0  3.87   99.0   0.0   0.0
# 1  6144.0  6144.0  117.0  84.0  ...   197.0  56.0  3.85   98.0   0.0   0.0
# 2  6582.0  6582.0  132.0  82.0  ...   228.0  57.0  5.55  100.0   0.0   0.0
# 3  6624.0  6624.0  115.0  76.0  ...   257.0  53.0  3.31  101.0   0.0   0.0
# 4  6346.0  6346.0  125.0  80.0  ...   228.0  53.0  4.31   99.0   0.0   0.0
#
#     PRCP  TAVG  TMAX  TMIN
# ...

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(30,15))
plt.style.use('seaborn-darkgrid')
plt.grid(True)
plt.plot(East_Asia["DATE"],East_Asia["TMAX"],label="East Asia")
plt.xlabel("Year",fontsize=20)
plt.ylabel("Maximum Temperature (F)",fontsize=20)
plt.title('Regional Temperatures (1970-2018)', color='red', fontsize=20, fontweight=5)
plt.plot(Europe["DATE"],Europe["TMAX"],label="Europe")
plt.plot(North_Africa["DATE"],North_Africa["TMAX"],label="North Africa")
plt.plot(Latin_America["DATE"],Latin_America["TMAX"],label="Latin America")
plt.plot(North_America["DATE"],North_America["TMAX"],label="North America")
plt.plot(South_Asia["DATE"],South_Asia["TMAX"],label="South Asia")
#plt.legend(loc='upper left',prop={'size':15})

plt.text(Europe['DATE'].tail(1), Europe['TMAX'].tail(1), 'Europe', size='medium', horizontalalignment='left',fontsize=20, color="orange")
plt.text(North_Africa['DATE'].tail(1), North_Africa['TMAX'].tail(1), 'North Africa', size='medium', horizontalalignment='left',fontsize=20,color="green")
plt.text(North_America['DATE'].tail(1)-2.3, North_America['TMAX'].tail(1)-1, 'North America', size='medium', horizontalalignment='left',fontsize=20, color="purple")
plt.text(Latin_America['DATE'].tail(1), Latin_America['TMAX'].tail(1), 'Latin America', size='medium', horizontalalignment='left',fontsize=20, color="red")
plt.text(East_Asia['DATE'].tail(1), East_Asia['TMAX'].tail(1), 'East Asia', size='medium', horizontalalignment='left',fontsize=20,color="blue")
plt.text(South_Asia['DATE'].tail(1), South_Asia['TMAX'].tail(1), 'South Asia', size='medium', horizontalalignment='left',fontsize=20,color="brown")

plt.savefig("temperature_trend.png")

# %%
plt.figure(figsize=(30,15))
plt.style.use('seaborn-darkgrid')
plt.grid(True)

plt.plot(East_Asia["DATE"],East_Asia["PRCP"],label="East Asia")
plt.xlabel("Year", fontsize=20)
plt.ylabel("Precipitation", fontsize=20)
plt.title('Regional Precipitation (1970-2018)', color='red', fontsize=20, fontweight=5)
plt.plot(Europe["DATE"],Europe["PRCP"],label="Europe")
plt.plot(North_Africa["DATE"],North_Africa["PRCP"],label="North Africa")
#plt.plot(Latin_America["DATE"],Latin_America["PRCP"],label="Latin America")
plt.plot(North_America["DATE"],North_America["PRCP"],label="North America")
plt.plot(South_Asia["DATE"],South_Asia["PRCP"],label="South Asia")
#plt.legend(loc='upper left',prop={'size':15})

plt.text(Europe['DATE'].tail(1), Europe['PRCP'].tail(1), 'Europe', size='medium', horizontalalignment='left',fontsize=20, color="orange")
plt.text(1998, 4.09, 'North Africa', size='medium', horizontalalignment='left',fontsize=20,color="green")
plt.text(North_America['DATE'].tail(1)-2.3, North_America['PRCP'].tail(1)-1, 'North America', size='medium', horizontalalignment='left',fontsize=20, color="red")
#plt.text(Latin_America['DATE'].tail(1), Latin_America['PRCP'].tail(1), 'Latin America', size='medium', horizontalalignment='left',fontsize=20, color="red")
plt.text(East_Asia['DATE'].tail(1), East_Asia['PRCP'].tail(1), 'East Asia', size='medium', horizontalalignment='left',fontsize=20,color="blue")
plt.text(2004, 49.23, 'South Asia', size='medium', horizontalalignment='left',fontsize=20,color="purple")

plt.savefig("precipitation_trend.png")
